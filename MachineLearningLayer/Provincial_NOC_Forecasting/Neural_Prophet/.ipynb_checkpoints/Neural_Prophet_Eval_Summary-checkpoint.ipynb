# %%
import pandas as pd 
import plotly.express as px
import plotly.graph_objects as go
from scipy import stats

# %%
df_Forecast = pd.read_parquet('Data/All_Forecasts.parquet')
df_Metrics = pd.read_csv('Data/Evaluation_Metrics.csv')

# %%
df_Metrics
# Out:
#      provinceid province_shorthand  noc_groupingid  \
# 0            12                 NS              15
# 1            13                 NB              60
# 2            46                 MB              55
# 3            24                 QC              48
# 4            59                 BC               6
# ..          ...                ...             ...
# 569          48                 AB              12
# 570          24                 QC              13
# 571          48                 AB              41
# 572          24                 QC              27
# 573          59                 BC              12
#
#                                           noc_grouping           r2  \
# 0    Assisting occupations in education and in lega...     0.988193
# 1    Occupations in front-line public protection se...     0.986617
# 2    Care providers and public protection support o...     0.956996
# 3    Management occupations [00, 10, 20, 30, 40, 50...     0.915886
# 4        Nursing and allied health professionals [313]     0.881726
# ..                                                 ...          ...
# 569  Professional occupations in natural and applie...  -402.919260
# 570  Technical trades and transportation officers a...  -489.324804
# 571                     Total, all occupations [00-95]  -589.258538
# 572  Middle management occupations in retail and wh...  -603.059560
# 573  Professional occupations in natural and applie... -9831.000376
#
#      euclidean distance         mae         rmse           mse  \
# 0              0.046101    0.029685     0.032598  1.062659e-03
# 1              0.057261    0.040426     0.040489  1.639383e-03
# 2              0.307934    0.161062     0.217742  4.741166e-02
# 3              7.833965    5.453204     5.539450  3.068551e+01
# 4              2.626350    1.678927     1.857110  3.448857e+00
# ..                  ...         ...          ...           ...
# 569          905.293337  181.647514   197.551202  3.902648e+04
# 570         1375.600218  254.583646   300.180577  9.010838e+04
# 571         4843.300599  920.233015  1056.894839  1.117027e+06
# 572          926.986861  120.517688   202.285117  4.091927e+04
# 573           91.148452   47.651048    64.451689  4.154020e+03
#
#      Average Actual   CV RMSE    CV MAE        MAPE
# 0          8.000000  0.004075  0.003711    0.377911
# 1          1.950000  0.020764  0.020731    2.163692
# 2          3.950000  0.055125  0.040775    5.448620
# 3        411.800000  0.013452  0.013242    1.338082
# 4         58.600000  0.031691  0.028651    3.015491
# ..              ...       ...       ...         ...
# 569      143.261905  1.378951  1.267940  127.749357
# 570      342.395238  0.876708  0.743537   73.763026
# 571     2543.428571  0.415539  0.361808   36.400726
# 572      110.495238  1.830713  1.090705  108.047133
# 573      184.150000  0.349996  0.258762   25.959722
#
# [574 rows x 13 columns]

# %%
df_Metrics.dtypes
# Out:
# provinceid              int64
# province_shorthand     object
# noc_groupingid          int64
# noc_grouping           object
# r2                    float64
# euclidean distance    float64
# mae                   float64
# rmse                  float64
# mse                   float64
# Average Actual        float64
# CV RMSE               float64
# CV MAE                float64
# MAPE                  float64
# dtype: object

# %%
df_Main_Metrics = df_Metrics[['CV RMSE','CV MAE','MAPE','euclidean distance']].describe().round(3).reset_index()

# %%
df_Main_Metrics.to_csv('Neural_Prophet_Summary.csv',index=False)
